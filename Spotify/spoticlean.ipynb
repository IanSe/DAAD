# %%
import pandas as pd
import numpy as np 
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('./spotify.csv', encoding='latin-1')
print(df.head())
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
for i in range(0, len(df)):
    if(type(df['in_shazam_charts'][i]) == str):
        df.loc[i, 'in_shazam_charts'] = df['in_shazam_charts'][i].replace(',', '')
        int(df['in_shazam_charts'][i])
    else:
        df.loc[i, 'in_shazam_charts'] = 0

print(df[['in_spotify_charts', 'in_deezer_charts', 'in_apple_charts','in_shazam_charts']].corr())
# Out:
#                    in_spotify_charts  in_deezer_charts  in_apple_charts  \
# in_spotify_charts           1.000000          0.600205         0.552232
# in_deezer_charts            0.600205          1.000000         0.383668
# in_apple_charts             0.552232          0.383668         1.000000
# in_shazam_charts            0.569568          0.395786         0.401411
#
#                    in_shazam_charts
# in_spotify_charts          0.569568
# in_deezer_charts           0.395786
# in_apple_charts            0.401411
# in_shazam_charts           1.000000

# %%
df.loc[900:952, ['track_name', 'in_spotify_charts', 'in_deezer_charts', 'in_apple_charts','in_shazam_charts']]
# Out:
#                                 track_name  in_spotify_charts  \
# 900                              Forget Me                  4
# 901                             After LIKE                 12
# 902                                Bound 2                  7
# 903  B.O.T.A. (Baddest Of Them All) - Edit                  6
# 904                         Talk that Talk                  0
# 905                         BILLIE EILISH.                  0
# 906                             Ferxxo 100                 30
# 907               KU LO SA - A COLORS SHOW                  8
# 908                             Prohibidox                 12
# 909                                 Static                  0
# 910                          The Scientist                  6
# 911                                 Sparks                  4
# 912                                   Talk                  0
# 913                       XQ Te Pones Asï¿                  0
# ...

# %%
df.loc[0:52, ['track_name', 'in_spotify_charts', 'in_deezer_charts', 'in_apple_charts','in_shazam_charts']]
# Out:
#                                            track_name  in_spotify_charts  \
# 0                 Seven (feat. Latto) (Explicit Ver.)                147
# 1                                                LALA                 48
# 2                                             vampire                113
# 3                                        Cruel Summer                100
# 4                                      WHERE SHE GOES                 50
# 5                                            Sprinter                 91
# 6                                     Ella Baila Sola                 50
# 7                                            Columbia                 43
# 8                                            fukumean                 83
# 9                                     La Bebe - Remix                 44
# 10                                          un x100to                 40
# 11                                          Super Shy                 55
# ...
